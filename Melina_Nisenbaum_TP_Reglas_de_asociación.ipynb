# %% [markdown]
# <a href="https://colab.research.google.com/github/melinanisenbaum/Datawarehouse/blob/main/Melina_Nisenbaum_TP_Reglas_de_asociaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cargamos la librería que nos permite acceder al dataset

# %%
# soporte para cargar dataset de https://www.openml.org/
# !pip install openml
import openml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.6/127.6 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 kB 3.8 MB/s eta 0:00:00
# ...
#   Created wheel for openml: filename=openml-0.13.1-py3-none-any.whl size=142798 sha256=582f5b88a88567445f086d7ec6378c46d92a4160d4181f2182c900611898db85
#   Stored in directory: /root/.cache/pip/wheels/f7/7a/fa/f73edc5ccecbab13bbf5fb888f2f943720f77114a1fa4ceffe
# ...
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11732 sha256=804e30a0005b69f45c84c73d37c593381e14e6006aa58671bff225529ed3d9e4
#   Stored in directory: /root/.cache/pip/wheels/5d/2a/9c/3895d9617f8f49a0883ba686326d598e78a1c2f54fe3cae86d
# Successfully built openml liac-arff
# ...

# %% [markdown]
# Accedemos al dataset

# %%
import pandas as pd

# indicamos cual dataset queremos utilizar, en este caso el nro. 24
dataset = openml.datasets.get_dataset(24)

# separamos las información almacenada en el dataset
X, y, categorical_indicator, attribute_names = dataset.get_data(
    dataset_format='dataframe',
    target=dataset.default_target_attribute
)

#  concatenamos la información relevante en un único DataFrame 
df = pd.concat([X, y], axis=1)
df
# Out:
#      cap-shape cap-surface cap-color bruises%3F odor gill-attachment  \
# 0            x           s         n          t    p               f
# 1            x           s         y          t    a               f
# 2            b           s         w          t    l               f
# 3            x           y         w          t    p               f
# 4            x           s         g          f    n               f
# ...        ...         ...       ...        ...  ...             ...
# 8119         k           s         n          f    n               a
# 8120         x           s         n          f    n               a
# 8121         f           s         n          f    n               a
# 8122         k           y         n          f    y               f
# 8123         x           s         n          f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cap-shape                 8124 non-null   category
#  1   cap-surface               8124 non-null   category
#  2   cap-color                 8124 non-null   category
#  3   bruises%3F                8124 non-null   category
#  4   odor                      8124 non-null   category
#  5   gill-attachment           8124 non-null   category
#  6   gill-spacing              8124 non-null   category
#  7   gill-size                 8124 non-null   category
#  8   gill-color                8124 non-null   category
#  9   stalk-shape               8124 non-null   category
#  10  stalk-root                5644 non-null   category
#  11  stalk-surface-above-ring  8124 non-null   category
#  12  stalk-surface-below-ring  8124 non-null   category
# ...

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5644 entries, 0 to 8114
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cap-shape                 5644 non-null   category
#  1   cap-surface               5644 non-null   category
#  2   cap-color                 5644 non-null   category
#  3   bruises%3F                5644 non-null   category
#  4   odor                      5644 non-null   category
#  5   gill-attachment           5644 non-null   category
#  6   gill-spacing              5644 non-null   category
#  7   gill-size                 5644 non-null   category
#  8   gill-color                5644 non-null   category
#  9   stalk-shape               5644 non-null   category
#  10  stalk-root                5644 non-null   category
#  11  stalk-surface-above-ring  5644 non-null   category
#  12  stalk-surface-below-ring  5644 non-null   category
# ...

# %%
cols = ['cap-shape', 'cap-surface', 'cap-color','bruises%3F', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat', 'class']
for col in cols:
  print(f'Columna {col}: {df[col].nunique()}subniveles')
# Out:
# Columna cap-shape: 6subniveles
# Columna cap-surface: 4subniveles
# Columna cap-color: 8subniveles
# Columna bruises%3F: 2subniveles
# Columna odor: 7subniveles
# Columna gill-attachment: 2subniveles
# Columna gill-spacing: 2subniveles
# Columna gill-size: 2subniveles
# Columna gill-color: 9subniveles
# Columna stalk-shape: 2subniveles
# Columna stalk-root: 4subniveles
# Columna stalk-surface-above-ring: 4subniveles
# Columna stalk-surface-below-ring: 4subniveles
# Columna stalk-color-above-ring: 7subniveles
# Columna stalk-color-below-ring: 7subniveles
# Columna veil-type: 1subniveles
# Columna veil-color: 2subniveles
# Columna ring-number: 3subniveles
# Columna ring-type: 4subniveles
# Columna spore-print-color: 6subniveles
# Columna population: 6subniveles
# Columna habitat: 6subniveles
# Columna class: 2subniveles

# %%
df.drop('veil-type', axis=1)
# Out:
#      cap-shape cap-surface cap-color bruises%3F odor gill-attachment  \
# 0            x           s         n          t    p               f
# 1            x           s         y          t    a               f
# 2            b           s         w          t    l               f
# 3            x           y         w          t    p               f
# 4            x           s         g          f    n               f
# ...        ...         ...       ...        ...  ...             ...
# 7986         b           y         n          f    n               f
# 8001         x           y         n          f    n               f
# 8038         x           y         g          t    n               f
# 8095         x           y         c          f    m               f
# 8114         f           y         c          f    m               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# ...

# %%
print(f'Set con filas repetidas: {df.shape}')
# Out:
# Set con filas repetidas: (5644, 23)

# %%
df.drop_duplicates(inplace=True)

# %%
print(f'Set con filas sin repetr: {df.shape}')
# Out:
# Set con filas sin repetr: (5644, 23)

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(df).transform(df)
data = pd.DataFrame(te_ary, columns=te.columns_)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-909232d15d2f> in <cell line: 5>()
#       3
#       4 te = TransactionEncoder()
# ----> 5 te_ary = te.fit(df).transform(df)
#       6 data = pd.DataFrame(te_ary, columns=te.columns_)
#       7 data
#
# NameError: name 'df' is not defined

# %%
df_dummy = pandas.get_dummies(df[['cap-shape', 'cap-surface', 'cap-color', 'odor', 'gill-attachment', 'gill-spacing', 'gill-color', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']])
df_dummy.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-25effc4f4e79> in <cell line: 1>()
# ----> 1 df_dummy = pandas.get_dummies(df[['cap-shape', 'cap-surface', 'cap-color', 'odor', 'gill-attachment', 'gill-spacing', 'gill-color', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']])
#       2 df_dummy.head()
#
# NameError: name 'pandas' is not defined
